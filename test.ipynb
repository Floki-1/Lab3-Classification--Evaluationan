# %%
isak=["isak","isak","isak","isak","isak"]
for i in isak:
    print("kassiworrier: " + i)
    for j in isak:
        print("Riktiga isak är : " + j)
# Out:
# kassiworrier: isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# kassiworrier: isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# kassiworrier: isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# kassiworrier: isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# kassiworrier: isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# Riktiga isak är : isak
# Riktiga isak är : isak
